# %%
import pandas as pd
from tqdm import tqdm
import math
tqdm.pandas()

# %%
# Negative sample
df_negative_sample = pd.read_csv('../data/processed/negative_sample.csv')

# Positive sample
df_positive_sample = pd.read_csv('../data/processed/positive_sample.csv')

# %%
# Negative Sample
#Cyclical Encoding of TIme Features
df_negative_sample['hour_sin'] = df_negative_sample.progress_apply(lambda row: math.sin(2 * math.pi * row['hour']/23.0),axis=1)
df_negative_sample['hour_cos'] = df_negative_sample.progress_apply(lambda row: math.cos(2 * math.pi * row['hour']/23.0),axis=1)
df_negative_sample['month_sin'] = df_negative_sample.progress_apply(lambda row: math.sin(2 * math.pi * row['month']/12.0),axis=1)
df_negative_sample['month_cos'] = df_negative_sample.progress_apply(lambda row: math.cos(2 * math.pi * row['month']/12.0),axis=1)
df_negative_sample = df_negative_sample.drop(['Unnamed: 0'], axis=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 260702/260702 [00:05<00:00, 48651.46it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 260702/260702 [00:05<00:00, 51333.17it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 260702/260702 [00:05<00:00, 50820.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 260702/260702 [00:04<00:00, 52222.22it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c7510e3bcf60> in <module>
#       5 df_negative_sample['month_sin'] = df_negative_sample.progress_apply(lambda row: math.sin(2 * math.pi * row['month']/12.0),axis=1)
#       6 df_negative_sample['month_cos'] = df_negative_sample.progress_apply(lambda row: math.cos(2 * math.pi * row['month']/12.0),axis=1)
# ----> 7 df_negative_sample = df_negative_sample.drop(['Unnamed: 0'])
#
# c:\users\bened\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# c:\users\bened\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# c:\users\bened\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# c:\users\bened\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df_negative_sample
# Out:
#         hour  year  month  weekday  segment_id   col_id  collision_cnt  \
# 0          1  2019     11        6       42796      NaN            NaN
# 1          4  2020      1        6       34322      NaN            NaN
# 2          9  2018      6        2       29497  11149.0            1.0
# 3          7  2020      9        6       39002      NaN            NaN
# 4          0  2019      7        2       32881      NaN            NaN
# ...      ...   ...    ...      ...         ...      ...            ...
# 260697    21  2020     12        7       27320      NaN            NaN
# 260698    17  2018     12        3       42549      NaN            NaN
# 260699     9  2020      1        7       29192      NaN            NaN
# 260700    22  2018      9        2       35074      NaN            NaN
# 260701     4  2018      6        6       16721      NaN            NaN
#
#         objectid  land  district  ...                         geometry  \
# 0            NaN   NaN       NaN  ...                              NaN
# 1            NaN   NaN       NaN  ...                              NaN
# 2       206132.0  11.0      10.0  ...  POINT (13.61992052 52.54395096)
# 3            NaN   NaN       NaN  ...                              NaN
# 4            NaN   NaN       NaN  ...                              NaN
# ...          ...   ...       ...  ...                              ...
# 260697       NaN   NaN       NaN  ...                              NaN
# 260698       NaN   NaN       NaN  ...                              NaN
# 260699       NaN   NaN       NaN  ...                              NaN
# 260700       NaN   NaN       NaN  ...                              NaN
# 260701       NaN   NaN       NaN  ...                              NaN
#
#        collision    mid_lat    mid_lon    length_m  side_strt  hour_sin  \
# 0              0  13.129002  52.444120  159.024842        1.0  0.269797
# 1              0  13.249398  52.425494   28.299309        1.0  0.887885
# 2              0  13.619756  52.543181  220.590194        1.0  0.631088
# 3              0  13.541896  52.485818   63.054032        1.0  0.942261
# 4              0  13.181491  52.503651  168.705271        1.0  0.000000
# ...          ...        ...        ...         ...        ...       ...
# 260697         0  13.518016  52.464331   63.193738        1.0 -0.519584
# 260698         0  13.507398  52.519448   36.050632        0.0 -0.997669
# 260699         0  13.587561  52.484598  121.979985        1.0  0.631088
# 260700         0  13.120203  52.472238  142.741320        1.0 -0.269797
# 260701         0  13.413085  52.399731  114.216127        1.0  0.887885
#
#         hour_cos     month_sin     month_cos
# 0       0.962917 -5.000000e-01  8.660254e-01
# 1       0.460065  5.000000e-01  8.660254e-01
# 2      -0.775711  1.224647e-16 -1.000000e+00
# 3      -0.334880 -1.000000e+00 -1.836970e-16
# 4       1.000000 -5.000000e-01 -8.660254e-01
# ...          ...           ...           ...
# 260697  0.854419 -2.449294e-16  1.000000e+00
# 260698 -0.068242 -2.449294e-16  1.000000e+00
# 260699 -0.775711  5.000000e-01  8.660254e-01
# 260700  0.962917 -1.000000e+00 -1.836970e-16
# 260701  0.460065  1.224647e-16 -1.000000e+00
#
# [260702 rows x 38 columns]

# %%
# Positive Sample
#Cyclical Encoding of TIme Features
df_positive_sample['hour_sin'] = df_positive_sample.progress_apply(lambda row: math.sin(2 * math.pi * row['hour']/23.0),axis=1)
df_positive_sample['hour_cos'] = df_positive_sample.progress_apply(lambda row: math.cos(2 * math.pi * row['hour']/23.0),axis=1)
df_positive_sample['month_sin'] = df_positive_sample.progress_apply(lambda row: math.sin(2 * math.pi * row['month']/12.0),axis=1)
df_positive_sample['month_cos'] = df_positive_sample.progress_apply(lambda row: math.cos(2 * math.pi * row['month']/12.0),axis=1)
df_positive_sample = df_positive_sample.drop(['Unnamed: 0'], axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 52118/52118 [00:01<00:00, 47293.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 52118/52118 [00:00<00:00, 52566.16it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 52118/52118 [00:01<00:00, 44091.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 52118/52118 [00:00<00:00, 52472.23it/s]

# %%
df_positive_sample
# Out:
#        col_id  segment_id  collision_cnt  objectid  land  district  \
# 0           1     41373.0              1    112705    11        12
# 1           3       828.0              6    112737    11         7
# 2           4     21397.0              2    112747    11         3
# 3           6     41696.0              1    112792    11         4
# 4           7     42255.0              2    112805    11         3
# ...       ...         ...            ...       ...   ...       ...
# 52113   38472     21737.0              6    145557    11         1
# 52114   38511      2782.0             20    145596    11         1
# 52115   38536      2781.0             21    145621    11         1
# 52116   38556     19720.0             14    145641    11         3
# 52117   38805      2781.0             21    145971    11         1
#
#               LOR                         street  LOR_ab_2021  year  ...  \
# 0      12304314.0     Ziekowstraße/Freie Scholle   12500824.0  2018  ...
# 1       7020202.0  Volkspark (Rudolf-Wilde-Park)    7200308.0  2018  ...
# 2       3020209.0              Niederschönhausen    3200206.0  2018  ...
# 3       4061757.0                Forst Grunewald    4200207.0  2018  ...
# 4       3010104.0                  Lietzengraben    3100101.0  2018  ...
# ...           ...                            ...          ...   ...  ...
# 52113   1044201.0                            NaN    1401045.0  2020  ...
# 52114   1044201.0                            NaN    1401045.0  2020  ...
# 52115   1044201.0                            NaN    1401045.0  2020  ...
# 52116   3061228.0                            NaN    3601245.0  2020  ...
# 52117   1044201.0                            NaN    1401045.0  2020  ...
#
#                               geometry  collision    mid_lat    mid_lon  \
# 0      POINT (13.29102205 52.58725906)          1  13.289303  52.589676
# 1      POINT (13.34828776 52.48184447)          1  13.347565  52.482210
# 2      POINT (13.40322797 52.58347154)          1  13.403247  52.583373
# 3      POINT (13.25639043 52.48571541)          1  13.248260  52.478908
# 4      POINT (13.42725182 52.63382261)          1  13.427264  52.633692
# ...                                ...        ...        ...        ...
# 52113  POINT (13.37741627 52.55626636)          1  13.378833  52.558438
# 52114  POINT (13.38326526 52.55611156)          1  13.382865  52.555996
# 52115  POINT (13.37597435 52.55638286)          1  13.375414  52.556590
# 52116   POINT (13.43157439 52.5507971)          1  13.432055  52.550425
# 52117  POINT (13.37624367 52.55636119)          1  13.375414  52.556590
#
#           length_m  side_strt  hour_sin  hour_cos     month_sin  month_cos
# 0       764.663725        0.0  0.136167 -0.990686  5.000000e-01   0.866025
# 1       141.626937        0.0 -0.997669 -0.068242  5.000000e-01   0.866025
# 2        96.715676        0.0 -0.816970 -0.576680  5.000000e-01   0.866025
# 3      1965.137281        0.0 -0.997669 -0.068242  5.000000e-01   0.866025
# 4       678.697900        0.0 -0.942261 -0.334880  5.000000e-01   0.866025
# ...            ...        ...       ...       ...           ...        ...
# 52113   475.840380        0.0 -0.136167 -0.990686 -2.449294e-16   1.000000
# 52114   189.106659        0.0 -0.997669 -0.068242 -2.449294e-16   1.000000
# 52115   225.940036        0.0  0.398401 -0.917211 -2.449294e-16   1.000000
# 52116   302.232453        0.0 -0.816970 -0.576680 -2.449294e-16   1.000000
# 52117   225.940036        0.0  0.631088 -0.775711 -2.449294e-16   1.000000
#
# [52118 rows x 38 columns]

# %%
# EXPORT
df_negative_sample.to_csv('../data/processed/negative_sample.csv')
df_positive_sample.to_csv('../data/processed/positive_sample.csv')
