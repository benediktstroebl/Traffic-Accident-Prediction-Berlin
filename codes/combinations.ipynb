# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
# import collision_road matching data with segment IDs
df_collisions_road = pd.read_csv('/content/drive/MyDrive/GRAD-C24_Machine_Learning/Machine-Learning-Project-Group-F/data/output/collisions_road.csv',
                            index_col=[0])

# import collision data
df_collisions = pd.read_csv('/content/drive/MyDrive/GRAD-C24_Machine_Learning/Machine-Learning-Project-Group-F/data/output/collisions.csv',
                            index_col=[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (5,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_collisions_road.head()
# Out:
#                   street  segment_id                    bezirk  \
# col_id
# 0       Samariterviertel        6210               Lichtenberg
# 0       Samariterviertel        6208  Friedrichshain-Kreuzberg
# 0       Samariterviertel       21094  Friedrichshain-Kreuzberg
# 0       Samariterviertel       21046  Friedrichshain-Kreuzberg
# 0       Samariterviertel       21058  Friedrichshain-Kreuzberg
#
#              stadtteil         strassenna
# col_id
# 0          Lichtenberg  Frankfurter Allee
# 0       Friedrichshain  Frankfurter Allee
# 0       Friedrichshain      Jessnerstraße
# 0       Friedrichshain  Pettenkoferstraße
# 0       Friedrichshain      Rigaer Straße

# %%
# generate all dates from start to end
import time
import datetime



start = "01/01/2018"
end = "01/03/2018"
date = datetime.datetime.strptime(start, "%d/%m/%Y")

dates = list()
while(date != datetime.datetime.strptime(end, "%d/%m/%Y")): 
    date += datetime.timedelta(days=1)
    for i in range(24):
        dates.append((date.strftime("%Y-%m-%d"), i))

# %%
df_date_hour_pairs.head()
# Out:
#          date  hour
# 0  2018-01-02     0
# 1  2018-01-02     1
# 2  2018-01-02     2
# 3  2018-01-02     3
# 4  2018-01-02     4

# %%
# Create the pandas DataFrame
df_date_hour_pairs = pd.DataFrame(dates, columns = ['date', 'hour'])
df_segments = pd.DataFrame(df_collisions_road["segment_id"].unique(), columns=["segment_id"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-701b8097ca57> in <module>()
#       1 # Create the pandas DataFrame
# ----> 2 df_date_hour_pairs = pd.DataFrame(dates, columns = ['date', 'hour'])
#       3 df_segments = pd.DataFrame(df_collisions_road["segment_id"].unique(), columns=["segment_id"])
#
# NameError: name 'pd' is not defined

# %%
df_segments.head()
# Out:
#    segment_id
# 0        6210
# 1        6208
# 2       21094
# 3       21046
# 4       21058

# %%
len(df_segments) * len(df_date_hour_pairs)
# Out:
# 288724800

# %%
### Creating Date-Hour-Road Segment Combinations

df_combinations = pd.merge(df_segments, 
                           df_date_hour_pairs, 
                           how='cross')

# %%
df_combinations
# Out:
#           segment_id        date  hour
# 0               6210  2018-01-02     0
# 1               6210  2018-01-02     1
# 2               6210  2018-01-02     2
# 3               6210  2018-01-02     3
# 4               6210  2018-01-02     4
# ...              ...         ...   ...
# 46798795       22566  2018-03-01    19
# 46798796       22566  2018-03-01    20
# 46798797       22566  2018-03-01    21
# 46798798       22566  2018-03-01    22
# 46798799       22566  2018-03-01    23
#
# [46798800 rows x 3 columns]
