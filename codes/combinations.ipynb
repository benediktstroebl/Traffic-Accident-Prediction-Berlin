# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
# import collision data
df_collisions = pd.read_csv('/content/drive/MyDrive/GRAD-C24_Machine_Learning/Machine-Learning-Project-Group-F/data/output/collisions.csv',
                            index_col=[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (5,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_collisions
# Out:
#        collision_id  land  district         LOR  \
# 0            112695    11         2   2050602.0
# 1            112705    11        12  12304314.0
# 2            112726    11         2   2040501.0
# 3            112737    11         7   7020202.0
# 4            112747    11         3   3020209.0
# ...             ...   ...       ...         ...
# 38847        146061    11         7   7040403.0
# 38848        146062    11        12  12231101.0
# 38849        146065    11         1   1011306.0
# 38850        146068    11         1   1011204.0
# 38851        146070    11         1   1033101.0
#
#                               street  LOR_ab_2021  year  month  hour  weekday  \
# 0                   Samariterviertel    2500729.0  2018      1    15        4
# 1         Ziekowstraße/Freie Scholle   12500824.0  2018      1    11        2
# 2                         Barnimkiez    2400520.0  2018      1     9        3
# ...

# %%
##Generate Date Column

import time
import datetime

df_collisions["date"] = pd.to_datetime(df_collisions["year"] + "/" + df_collisions["month"] + "/" + df_collisions["weekday"])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-105-4d0cd3f764c7> in <module>()
#       4 import datetime
#       5
# ----> 6 df_collisions["date"] = pd.to_datetime(df_collisions["year"] + "/" + df_collisions["month"] + "/" + df_collisions["weekday"])
#       7
#       8
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __add__(self, other)
#      90     @unpack_zerodim_and_defer("__add__")
#      91     def __add__(self, other):
# ---> 92         return self._arith_method(other, operator.add)
#      93
#      94     @unpack_zerodim_and_defer("__radd__")
#
# ...

# %%
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True]

# %%
accidents_2019.head()
# Out:
#    OBJECTID  LAND  BEZ       LOR  UJAHR  UMONAT  USTUNDE  UWOCHENTAG  \
# 0     49090    11   12  12301203   2019       1       13           6
# 1     49091    11    3   3040818   2019       1        9           5
# 2     49093    11   12  12103115   2019       3       21           6
# 3     49096    11    6   6040703   2019       1        7           6
# 4     49097    11    7   7030303   2019       2       15           3
#
#    UKATEGORIE  UART  ...  IstPKW  IstFuss  IstKrad  IstGkfz  IstSonstige  \
# 0           3     5  ...       1        0        0        0            0
# 1           3     5  ...       1        0        0        0            0
# 2           3     0  ...       0        0        0        0            0
# 3           2     6  ...       1        1        0        0            0
# 4           3     2  ...       1        0        0        0            0
#
#    USTRZUSTAND      LINREFX      LINREFY XGCSWGS84 YGCSWGS84
# ...

# %%
accidents_2020['UMONAT'].max()
# Out:
# 12

# %%
# generate all dates from start to end
import time
import datetime



start = "01/01/2018"
end = "31/12/2020"
date = datetime.datetime.strptime(start, "%d/%m/%Y")

dates = list()
while(date != datetime.datetime.strptime(end, "%d/%m/%Y")): 
    date += datetime.timedelta(days=1)
    for i in range(24):
        dates.append((date.strftime("%Y-%m-%d"), i))

# %%
# Create the pandas DataFrame
df_date_hour_pairs = pd.DataFrame(dates, columns = ['date', 'hour'])
df_road_segments = pd.DataFrame(('00001',
                                 '00002',
                                 '00003',
                                 '00004',
                                 '00005'), columns=['segment_ID'])

# %%
len(df_road_segments) * len(df_date_hour_pairs)
# Out:
# 131400

# %%
### Creating Date-Hour-Road Segment Combinations

df_combinations = pd.merge(df_road_segments, 
                           df_date_hour_pairs, 
                           how='cross')

# %%
df_combinations
# Out:
#        segment_ID        date  hour
# 0           00001  2018-01-02     0
# 1           00001  2018-01-02     1
# 2           00001  2018-01-02     2
# 3           00001  2018-01-02     3
# 4           00001  2018-01-02     4
# ...           ...         ...   ...
# 131395      00005  2020-12-31    19
# 131396      00005  2020-12-31    20
# 131397      00005  2020-12-31    21
# 131398      00005  2020-12-31    22
# 131399      00005  2020-12-31    23
#
# [131400 rows x 3 columns]
